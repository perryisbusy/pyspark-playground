# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
raw_folder_path = "dbfs:/mnt/databrickssa1/raw/"
processed_folder_path = "dbfs:/mnt/databrickssa1/processed/"
presentation_folder_path = "dbfs:/mnt/databrickssa1/presentation/"
v_file_date = "2021-03-21"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# dbutils.widgets.help()
# Out:
# <div class = "ansiout"><b>dbutils.widgets</b> provides utilities for working with notebook widgets. You can create
# different types of widgets and get their bound value.
#
# For more info about a method, use <b>dbutils.widgets.help("methodName")</b>.
# ...

# %%
# dbutils.widgets.text("p_data_scource", "")
# v_data_source = dbutils.widgets.get("p_data_scource")
# v_data_source
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: &#39;configuration&#39;</div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">conf/  eventlogs/  ganglia/  logs/  preload_class.lst*
# </div>
