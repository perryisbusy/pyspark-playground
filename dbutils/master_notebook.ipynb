# %%
dbutils.notebook.run("./children_notebook", 0, {"entdffder123": "1ret56"})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: &#39;children_notebook&#39;</div>

# %%
dbutils.notebook.exit("master_notebook")
# Out:
# master_notebook
